# %%
# Dependencies
import numpy as np
import pandas as pd
import datetime as dt 
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import create_engine, func, inspect, extract

# %%
sqlite_path = "/Resources/hawaii.sqlite"
engine = create_engine(f"sqlite://{sqlite_path}")
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
print(Base.classes.keys())

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station
# Out:
# ['measurement', 'station']

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
june_temp = dt.date(2017, 8, 23) - dt.timedelta(days=83)

# %%
#  3. Convert the June temperatures to a list.
results = session.query(Measurement.date).filter(Measurement.date >=june_temp).all()
print(results)
# Out:
# [('2017-06-01',), ('2017-06-02',), ('2017-06-03',), ('2017-06-04',), ('2017-06-05',), ('2017-06-06',), ('2017-06-07',), ('2017-06-08',), ('2017-06-09',), ('2017-06-10',), ('2017-06-11',), ('2017-06-12',), ('2017-06-13',), ('2017-06-14',), ('2017-06-15',), ('2017-06-16',), ('2017-06-17',), ('2017-06-18',), ('2017-06-19',), ('2017-06-20',), ('2017-06-21',), ('2017-06-22',), ('2017-06-23',), ('2017-06-24',), ('2017-06-25',), ('2017-06-26',), ('2017-06-27',), ('2017-06-28',), ('2017-06-29',), ('2017-06-30',), ('2017-07-01',), ('2017-07-02',), ('2017-07-03',), ('2017-07-04',), ('2017-07-05',), ('2017-07-06',), ('2017-07-07',), ('2017-07-08',), ('2017-07-09',), ('2017-07-10',), ('2017-07-11',), ('2017-07-12',), ('2017-07-13',), ('2017-07-14',), ('2017-07-15',), ('2017-07-16',), ('2017-07-17',), ('2017-07-18',), ('2017-07-20',), ('2017-07-21',), ('2017-07-22',), ('2017-07-23',), ('2017-07-24',), ('2017-07-25',), ('2017-07-26',), ('2017-07-27',), ('2017-07-28',), ('2017-07-29',), ('2017-07-3
# ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
june_temp_df = pd.DataFrame(results, columns=['date'])

print(df)
# Out:
#            date  precipitation
# 0    2017-05-31           0.02
# 1    2017-06-01           0.00
# 2    2017-06-02           0.00
# 3    2017-06-03           0.02
# 4    2017-06-04           0.00
# ..          ...            ...
# 476  2017-08-19           0.09
# 477  2017-08-20            NaN
# 478  2017-08-21           0.56
# 479  2017-08-22           0.50
# 480  2017-08-23           0.45
#
# [481 rows x 2 columns]

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
june_temp_df.describe()
# Out:
#               date
# count          481
# unique          85
# top     2017-06-29
# freq             7

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.

# %%
# 7. Convert the December temperatures to a list.

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December.

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
